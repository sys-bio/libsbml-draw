# %%
from libsbml_draw.model.sbml_layout import SBMLlayout

# %%
model_file = "C:\\tmp\\model.xml"
sl = SBMLlayout(model_file)

# %%
sl.drawNetwork()

# %%
sl.setReactionColor("all", "green")
sl.setNodeEdgeColor("X0", "blue")

# %%
sl.drawNetwork("C:\\tmp\\model_compute_layout.png")

# %%
sl.writeSBMLFile("C:\\tmp\\model_with_layout_and_render.xml")
